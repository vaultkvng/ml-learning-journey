# %%
## Arithmetic Operation
a=10
b=5

result=a+b

print(result)
# Out:
# 15

# %%
## Subtraction Operation
result=a-b
print(result)
# Out:
# 5

# %%
## Multiplication Operation
result=a*b
print(result)
# Out:
# 50

# %%
## Division Operation
result=a/b
print(result)
# Out:
# 2.0

# %%
##
